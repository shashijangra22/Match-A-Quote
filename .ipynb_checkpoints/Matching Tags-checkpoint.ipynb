# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
iDataSet=pd.read_csv("imagedataset.csv")
qDataSet=pd.read_csv("Filtered_Quotes(0-1500).csv")

# %%
images=np.array(iDataSet)
quotes=np.array(qDataSet)

# %%
def MatchAQuote(qCats,quote,qTags):
    tempScore=[]
    for image in images:
        iName=image[0]
        iCats=image[1]
        iTags=image[2]
        matchCats=matchWords(qCats.split(','),iCats.split(','))
        matchTags=matchWords(qTags.split(','),iTags.split(','))
        score1=len(matchCats)
        score2=len(matchTags)
        if score1 and score2:
            details={
                "iName":iName,
                "scores":(score1,score2),
                "mCats":matchCats,
                "mTags":matchTags
            }
            tempScore.append(details)
    return tempScore

# %%
def matchWords(a,b):
    matches=[]
    for w in a:
        for i in b:
            if w.lower()==i.lower():
                matches.append(w.lower())
    return matches

# %%
def candidates(sample):
    cats=sample[0]
    quote=sample[1]
    tags=sample[2]
    print("Cats are: ",cats)
    print("Quote is: ",quote)
    print("Tags are: ",tags)
    tempScore=MatchAQuote(cats,quote,tags)
    print("\nMatched Candidates are: \n")
    for item in tempScore:
        imgName=item["iName"]
        print("image name: ",imgName)
        print("scores: ",item["scores"])
        print("Matched Cats are: ",item["mCats"])
        print("Matched Tags are: ",item["mTags"])
        print()
        plt.figure()
        head,sep,tail=imgName.partition('_')
        IMG=Image.open("../images/"+head+"/"+imgName+".png")
        plt.imshow(IMG)
        plt.show()

# %%
candidates(quotes[60])
# Out:
# Cats are:  arts
# Quote is:  Architecture is the art of how to waste space.
# Tags are:  Architecture,Space,history
#
# Matched Candidates are:
#
# image name:  arts_2
# scores:  (1, 1)
# Matched Cats are:  ['arts']
# Matched Tags are:  ['space']
# image name:  arts_10
# scores:  (1, 1)
# Matched Cats are:  ['arts']
# Matched Tags are:  ['architecture']
# image name:  arts_15
# scores:  (1, 1)
# Matched Cats are:  ['arts']
# Matched Tags are:  ['architecture']
# image name:  arts_19
# scores:  (1, 1)
# Matched Cats are:  ['arts']
# Matched Tags are:  ['architecture']
